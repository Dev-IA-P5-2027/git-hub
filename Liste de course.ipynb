# %% [markdown]
# Vous devez créer une fonction qui trie automatiquement des fichiers dans des sous-dossiers en fonction de leur type (et donc de leur extension). Facultatif : Réaliser la fonction inverse → déplacer les fichiers des sous-dossiers dans le dossier principale.

# %%
print("Salut")
# Out:
# Salut

# %%
Disque = {"Fichier" : 
          "Document" : [],
          "Image" : [],
          "Musique" 



def triefichier():
    Nom_du_fichier = input("Entre le nom du fichier")
    Extention = Nom_du_fichier.split(".")
    print(Extention[1])
    if Extention[1] == "pdf":
        #fichier go to Document
    if Extention[1] == "jpg":
        #Fichier go to Image
    if Extention[1] == "mp3":
        #Fichier go to Musique
    if Extention[1] == "mp4":
        #Fichier go to Videos
    


triefichier()
# Out:
# pdf
