# %%
Mots =(input("Entre le mot"))
print(Mots)
# Out:
# Salut !

# %%
def saisie_Fraction():
    Numérateur = int(input("Entre ton numérateur"))
    Dénominateur = int(input("Entre ton dénominateur"))
    # Fraction = [Numérateur,Dénominateur]
    return  [Numérateur, Dénominateur]

def Ecrit_Fraction(f):
    print(f"{f[0]}/{f[1]}")

def Multiplication(f1,f2):
    Numérateurf3 = f1[0] * f2[0]
    Dénominateurf3 = f1[1] * f2[1]
    return [Numérateurf3, Dénominateurf3]


def Addition(f1,f2):
    Numérateurf4 = f1[0] * f2[1] + f2[0] * f1[1]
    Dénominateurf4 = f1[1] * f2[1]
    return [Numérateurf4, Dénominateurf4]

# def simplification(f):
#     # while i n+1: si % i == 0 break
#     while f[0] % i == 0 and f[1] % i == 0:
#         for i in range(1,n+1):
#             i+=1
#             # Numérateur = f[1] // i
#             # print(Numérateur)
#             return [Numérateur]
        
    #     Dénominateur = f[1] % i == 0:
    # return [Numérateur, Dénominateur]

f1 = saisie_Fraction()
Ecrit_Fraction(f1)
f2 = saisie_Fraction()
Ecrit_Fraction(f2)
f3 = Multiplication(f1,f2)
Ecrit_Fraction(f3)
f4 = Addition(f4)
Ecrit_Fraction(f4)
# Addition(f1,f2)


# simplification(f1)
# Out:
# 1/2
# 1/2
# 1/4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 39
#      37 f3 = Multiplication(f1,f2)
#      38 Ecrit_Fraction(f3)
# ---> 39 f4 = Addition(f4)
#      40 Ecrit_Fraction(f4)
#      41 # Addition(f1,f2)
#      42
#      43
#      44 # simplification(f1)
#
# NameError: name 'f4' is not defined

# %%
import random

Resultat = []
n = int(input("Entre ton nombre de lancer"))

def Tirage():
    for i in range(0,n):
        Dés = random.randint(1,6)
        Resultat.append(Dés)
    return Resultat

def Analyse():
    for i in range(1,6):
        if Resultat[4] == i:
            print(je vois i)
            
    
Tirage()
Analyse()
# Out:
#   Cell In[42], line 15
#     print(je vois i)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import random

Resultat = [0,0,0,0,0,0]
n = int(input("Entre ton nombre de lancer"))

def Tirage():
    for i in range(0,n):
        Dés = random.randint(1,6)
        for y in range(1,6):
            if Dés == y:
                Resultat[y]+= 1
    return Resultat

def Fréquence():
    for str in Resultat:
        print(str/n)
    return 

Tirage()
Fréquence()

# %%
A = int(input("A"))
B = int(input("B"))
# A*X + B = 0 

def Equation_fonction_affine():
    if A != 0:
        X = -B/A
        print(f"Quand A est égal à {A}, et B est égal à {B}. X est égal à {X}")

Equation_fonction_affine()
# Out:
# Quand A est égal à 5, et B est égal à 6. X est égal à -1.2

# %%
A = int(input("A"))
B = int(input("B"))
# A*X + B >= 0 

def Equation_fonction_affine():
    if A != 0:
        X = -B/A
        print(f"Quand A est égal à {A}, et B est égal à {B}. X est égal à {X}")

def inEquation():
    if A != 0:
        X = -B/A
        print("Pour tout X appartenant à N")
        print(f"Quand A est égal à {A}, et B est égal à {B}. Les valeur >= X où X est égal à {X} sont solution")
        print(f"[{X}; {float('+inf')}[")



Equation_fonction_affine()
inEquation()
# Out:
# Quand A est égal à 1, et B est égal à 1. X est égal à -1.0
# Pour tout X appartenant à N
# Quand A est égal à 1, et B est égal à 1. Les valeur >= X où X est égal à -1.0 sont solution
# [-1.0; inf[
