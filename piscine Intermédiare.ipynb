# %%
# Exercice 10 : 
# Écrivez un script qui demande à l'utilisateur une chaine de caractères.
# Le script recopie la chaîne (dans une nouvelle variable), en insérant des astérisques entre les caractères.
# Par exemple, "gaston" devra devenir "g*a*s*t*o*n

Name = (input("Entre ton Nom"))
liste = list(Name)

# for str in liste:
#      liste.insert(1,"*")

# for letter in Name:
#     Name = list(mot)
#     # Eppeler = Name.split()
#     Eppeler.insert(1,"*")
print(liste)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 10
#       7 liste = list(Name)
#       9 for str in liste:
# ---> 10      liste.insert(1,"*")
#      12 # for letter in Name:
#      13 #     Name = list(mot)
#      14 #     # Eppeler = Name.split()
#      15 #     Eppeler.insert(1,"*")
#      16 print(liste)
#
# KeyboardInterrupt:

# %%
# Exercice 1 :
# Utilisez une exception pour calculer, dans une boucle évoluant de -3 à 3 compris, la valeur de sin(x)/x. L'exception permettra de gérer l'erreur rencontrée, de l'afficher et de continuer le programme.
import math
def sinus():
    for x in range(-3,3):
        sin(x)/x
    return 

sinus()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       6         sin(45)/x
#       7     return
# ----> 9 sinus()
#
# Cell In[13], line 6, in sinus()
#       4 def sinus():
#       5     for x in range(-3,3):
# ----> 6         sin(45)/x
#       7     return
#
# TypeError: sin() takes 0 positional arguments but 1 was given

# %%
# Exercie 2 :
# Écrire une fonction qui retourne f(x) = 2x3 + x − 5. Écrire une fonction poly avec quatre paramètres : fonction, borneInf, borneSup et nbPas. Cette procédure affiche les valeurs de fonction, de borneInf à borneSup, touslesnbPas. Elle doit respecter borne Inf < borne Sup.
import math
x = int(input("Entre un nombre x"))
Fx = 2*3 + x -5

def poly():
    BorneSup = max(Fx)
    BorneInf = min(Fx)
    print(f"{Fx} {BorneSup} {BorneInf}")
    # return Fx
    
    # clé = x
    # valeur = f(x)

poly()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 16
#      10     print(f"{Fx} {BorneSup} {BorneInf}")
#      11     # return Fx
#      12
#      13     # clé = x
#      14     # valeur = f(x)
# ---> 16 poly()
#
# Cell In[9], line 8, in poly()
#       7 def poly():
# ----> 8     BorneSup = max(Fx)
#       9     BorneInf = min(Fx)
#      10     print(f"{Fx} {BorneSup} {BorneInf}")
#
# TypeError: 'int' object is not iterable

# %%
# Exercice : 3
# Définir la liste : liste =[17, 38, 10, 25, 72] Puis effectuez les actions suivantes :
# – affichez la liste – ajoutez l’élément 12 à la liste et affichez là – affichez l’indice de l’élément 17 – enlevez l’élément 38 et affichez la liste – affichez la sous-liste du 2e au 3e élément – affichez la sous-liste du début au 2e élément – affichez le dernier élément en utilisant un indexage négatif.

ma_liste = [17, 38, 10, 25, 72]
print(ma_liste)

def addto():
    ma_liste.append(12)
    return ma_liste

addto()
print(ma_liste)

ma_liste.index(17)



ma_liste.remove(38)
print(ma_liste)

revoir truc dans débutant
ma_liste2 = ma_liste[1,2]
print(ma_liste)
pareille et encore pareille.
# Out:
# [17, 38, 10, 25, 72]
# [17, 38, 10, 25, 72, 12]
# [17, 10, 25, 72, 12]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 22
#      19 ma_liste.remove(38)
#      20 print(ma_liste)
# ---> 22 ma_liste2 = ma_liste[1,2]
#      23 print(ma_liste)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# Exercice 4 :
# Écrire une fonction compterMots ayant un argument (une chaîne de caractères) et qui renvoie un dictionnaire qui contient la fréquence de tous les mots de la chaîne entrée.
def compterMots():
    Mots = input("Choisie tes mots")
    Mots.split()
    return Mots

def CompterMots2():
    for any str in Mots:
        #nb str = chiffre voir le truc avec les lettre

compterMots()
# Out:
# 'Kevein à "t" mouillé par un nuage'

# %%
# Fonction renvoyant plusieurs valeurs sous forme d’un tuple. Écrire une fonction minMaxMoy qui reçoit une liste d’entiers et qui renvoie le minimum, le maximum et la moyenne de cette liste. Le programme principal appellera cette fonc- tion avec la liste : [10, 18, 14, 20, 12, 16]
import math

ma_liste = [10, 18, 14, 20, 12, 16]

def truc():
    print(f"{min(ma_liste)} {max(ma_liste)} moy(ma_liste)")

truc()
# Out:
# 10 20 moy(ma_liste)
