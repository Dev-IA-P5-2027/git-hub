# %%
# 1) Exercice 1 : bonjour
# Ecrire un programme qui affiche "bonjour".
# Bis : mettre ce programme dans une fonction bonjour() qui prend en paramètres le nombre de fois que la fonctionne affichera bonjour et tester cette fonction
def Bonjour():
        n = int(input("entre le nombre de répétition"))
        for i in range(0,n):
            print("Bonjour")

Bonjour()
# Out:
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour
# Bonjour

# %%
# 2) Exercice 2 :
# Écrire dans une cellule un programme qui demande à l'utilisateur de rentrer un rayon et la hauter, puis , qui calcule le volume d'un cône droit. (Rappel : Vcone = 1/3 * pi * r^2 * h) Bis : mettre ce programme dans une fonction volume_cone() et tester cette fonction

Rayon = int(input("rentre le rayon"))
Hauteur = int(input("rentre la hauteur"))
Volume = 1/3*3.14*Rayon**2*Hauteur
print(Volume)
# Out:
# 16.746666666666666

# %%
# 3) Exercice 3 :
# Écrire dans une cellule un programme qui demande à l'utilisateur son poids et sa taille et qui calcule son IMC (trouver la formule sur internet).
# Bis : mettre ce programme dans une fonction imc() et tester cette fonction

def calcul_IMC():
    Poids = int(input("entre ton poids en KG"))
    Taille = float(input("entre ta taille en m"))
    IMC = Poids/Taille**2
    print(IMC)

calcul_IMC()
# Out:
# 18.812147272238644

# %%
# 4) Exercice 4 : les distances
# Écrire une fonction qui convertit en mètres par seconde et en km/h une vitesse fournie en paramètres par l'utilisateur en miles/heure (1 mile = 1609 mètres). Ce résultat sera retourné par la fonction.

def Vitesse():
    Miles = int(input("entre ta vitesse en mille/h"))
    KM = Miles*1.609
    Ms = KM/3.6
    print(f"La vitesse du véhicule est de {KM} km/h et de {Ms} m/s")

Vitesse()
# Out:
# La vitesse du véhicule est de 32.18 km/h et de 8.938888888888888 m/s

# %%
# 5) Exercice 5 :
# Écrire dans une cellule un programme qui demande à l'utilisateur de rentrer un entier n positif et qui affiche PAIR s'il est divisible par 2, IMPAIR sinon (penser au modulo).
# Bis : mettre ce programme dans une fonction pair() et tester cette fonction

def pair():
    n = int(input("rentre un entier positif"))
    if n % 2 == 0 :
        print(f"n est pair")
    else:
        print(f"est impair")
pair()
# Out:
# n est pair

# %%
# 6) Exercice 6 :
# Écrire un programme en python pour réviser ses tables de multiplication. Le programme tire au hasard deux entiers entre 0 et 10 et demande à l'utilisateur de donner leur produit.
# Si l'utilisateur répond juste, il gagne un point. Si il répond faux, il perd un point.
# On interrogera 5 fois l'utilisateur.
# Le programme affiche à la fin le score de l'utilisateur.

import random

def Table_de_multiplication():
    Pts = 0
    for i in range(5):
        # A = math.random(0,10)
        A = random.randint(1,10)
        B = random.randint(1,10)
        print(f"{A}*{B}=")
        Réponse = int(input("entre ta réponse"))
        if Réponse == A*B:
            Pts+=1 
            print("Tu gagne un point")
            print(f"Tu as {Pts}")
        else:
            Pts-=1
            print("Tu perd un point")
            print(f"Tu as {Pts}")
        if Pts == 5:
            print("Tu as gagné")
        else:
            print("Suivant")

Table_de_multiplication()
# Out:
# 4*1=
# Tu gagne un point
# Tu as 1
# Suivant
# 3*9=
# Tu gagne un point
# Tu as 2
# Suivant
# 9*1=
# Tu gagne un point
# Tu as 3
# Suivant
# 8*10=
# Tu gagne un point
# Tu as 4
# Suivant
# 7*6=
# Tu perd un point
# Tu as 3
# Suivant

# %%
# 7) Exercice 7 : Devine un nombre
# L'ordinateur tire un nombre entier au hasard entre 0 et 100.
# L'utilisateur doit le trouver et pour cela propose des valeurs.
# L'ordinateur indique pour chaque valeur proposée si la valeur est trop petite, trop grande ou s'il a trouvé.
# a) Écrire un programme en Python pour jouer à ce jeu.
# b) Modifier le programme pour qu'il s'arrête si l'utilisateur n'a pas trouvé au bout de 10 coups.
# c) Mettre ce programme dans une fonction plus_ou_moins() qui prendra en paramètres :

# le nombre min et max de la plage de tirage du nombre au hasard
# le nombre de coups maximum


def plus_ou_moins():
    Nombre_à_trouver = random.randint(0,100)
    Nombre_proposer = int(input("Entre un nombre compris entre 0 et 100 pour trouver le nombre cacher'"))
    for i in range(0,10):
        while Nombre_proposer != Nombre_à_trouver:
            Nombre_proposer = int(input("Entre un nombre compris entre 0 et 100 pour trouver le nombre cacher'"))
            print(f"{Nombre_proposer}")
            if Nombre_proposer < Nombre_à_trouver:
                print("C'est plus grand")
            elif Nombre_proposer > Nombre_à_trouver:
                print("c'est plus petit")
        if Nombre_proposer == Nombre_à_trouver:
                print(f"Bravo tu as trouver que {Nombre_à_trouver} était le nombre cacher")
                break
plus_ou_moins()
# Out:
# 50
# C'est plus grand
# 90
# c'est plus petit
# 80
# c'est plus petit
# 70
# c'est plus petit
# 60
# C'est plus grand
# 65
# Bravo tu as trouver que 65 était le nombre cacher

# %%
# 8) Exercice 8 :
# Ecrire un programme qui tourne indéfiniement et qui demande à l'utilisateur de rentrer un nombre entier compris dans une plage définie aléatoirement (par exemple, entrer un nombre compris entre 12 et 34).
# Si le nombre entré est en dehors de la plage, le programme l'affiche et redemande à nouveau un nombre dans la même plage.
# Si le nombre entré est dans la plage, on félicite l'utilisateur et le programme reprend avec un nouvelle plage.
import random

def Generated():
    A = random.randint(1,50) #and A < B
    B = random.randint(51,100) #and B > A
    print(f"{A} et {B}")
    return A, B


def Entre_ton_numero():
    Numero = int(input("entre ton numéro"))
    print(f"ton numéro est le {Numero}")
    return Numero

def Random_Number():
    A, B = Generated()
    while True:
        Numero = Entre_ton_numero()
        if Numero >= A and Numero <= B:
            print("Tu es dans la plage bravo")
            break
        elif Numero <= A or Numero >= B:
            print("Tu n'est pas dans la boucle, recommence")     
            

while True:         
    Random_Number()
# Out:
# 12 et 54
# ton numéro est le 14
# Tu es dans la plage bravo
# 16 et 65
# ton numéro est le 52
# Tu es dans la plage bravo
# 10 et 79
# ton numéro est le 0
# Tu n'est pas dans la boucle, recommence
# ton numéro est le 1000
# Tu n'est pas dans la boucle, recommence
# ton numéro est le 45
# Tu es dans la plage bravo
# 39 et 86
# ton numéro est le 100
# Tu n'est pas dans la boucle, recommence
# ton numéro est le 47455
# Tu n'est pas dans la boucle, recommence
# ton numéro est le 545
# Tu n'est pas dans la boucle, recommence
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 31
#      27             print("Tu n'est pas dans la boucle, recommence")
#      30 while True:
# ---> 31     Random_Number()
#
# Cell In[1], line 22, in Random_Number()
#      20 A, B = Generated()
#      21 while True:
# ---> 22     Numero = Entre_ton_numero()
#      23     if Numero >= A and Numero <= B:
#      24         print("Tu es dans la plage bravo")
#
# Cell In[1], line 15, in Entre_ton_numero()
#      14 def Entre_ton_numero():
# ---> 15     Numero = int(input("entre ton numéro"))
#      16     print(f"ton numéro est le {Numero}")
#      17     return Numero
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Exercice 9
# Écrire un programme permettant d'entrer des notes d’élèves sur 20 jusqu’à ce l’utilisateur saisisse une note vide. Cette fonction retourne le nombre de notes entrées, la note la plus élevée, la note la plus basse, la moyenne de toutes les notes.
Note = []
# Max_Note = max(Note)
# Min_Note = min(Note)

def Addtolist():
    Note.append(int(input("entre la note de l'élève sur 20")))
    print(Note)
    return Note

while True :
    Addtolist()
    # if not Note.strip():
    print(f" La liste de note est {Note} le max étant {Max_Note} et le min étant {Min_Note}")
    
        # print(moy(Note)) if Note and str(Note[-1]) == "":
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Écrire un programme permettant d'entrer des notes d’élèves sur 20 jusqu’à ce l’utilisateur saisisse une note vide. Cette fonction retourne le nombre de notes entrées, la note la plus élevée, la note la plus basse, la moyenne de toutes les notes.
#       2 Note = []
# ----> 3 Max_Note = max(Note)
#       4 Min_Note = min(Note)
#       6 def Addtolist():
#
# ValueError: max() iterable argument is empty

# %%
code_bar = {}

Numéro = int(input("C'est ton numéro"))
# Nouriture = [ravioli, haricot, repas]}

def Entre_ton_numéro(Numéro):
    if Numéro == 0 :
    print("gf")
# Out:
#   Cell In[28], line 8
#     print("il n'est pas dans la plage")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 7

# %%
class skill :

def init(self, name, skill_id, level):
    self.name = name
    self.id = skill_id
    self.level = level
def init(self):
    print(f"{self.name}, {self.id}, {self.level}")
# Out:
#   Cell In[40], line 3
#     def init(self, name, skill_id, level):
#     ^
# IndentationError: expected an indented block after class definition on line 1

# %%
# Exercice 10 : 
# Écrivez un script qui demande à l'utilisateur une chaine de caractères.
# Le script recopie la chaîne (dans une nouvelle variable), en insérant des astérisques entre les caractères.
# Par exemple, "gaston" devra devenir "g*a*s*t*o*n

Name = (input("Entre ton Nom"))
Eppeler = Name.split()
print(Eppeler)
Eppeler.append("*")
# Out:
# ['gg']
